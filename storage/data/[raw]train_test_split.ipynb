# %%
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('[raw]transaction.csv')
data.reset_index()
# Out:
#          index             0              1            2            3  \
# 0            0 -42230.193526   -5101.387638 -1039.578439 -4103.881762
# 1            1 -42209.877926   -5117.633510 -1397.821642  6962.889312
# 2            2 -42236.157674   -5129.815276 -1398.873663  5004.767253
# 3            3 -42221.757393   -5119.656464  1311.218680 -8376.615388
# 4            4  36736.188237  163639.777560   679.947831  6236.709523
# ...        ...           ...            ...          ...          ...
# 590535  590535 -42231.474383   -5104.078630 -1274.631753  3234.327481
# 590536  590536 -42232.830315   -5127.018736 -1287.192105  -740.210969
# 590537  590537 -42232.875921   -5126.700730 -1257.544099 -2325.958728
# 590538  590538 -42245.327811   -5132.755788   689.944902  1824.181151
# 590539  590539 -42236.218958   -5128.429684  -824.911277 -5349.448048
#
#                   4            5            6            7            8  ...  \
# ...

# %%
x_data = data.drop('isFraud', axis=1)
y_data = data[['isFraud']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=777, stratify=y_data)

# %%
train = pd.concat([x_train, y_train], axis=1)
train.reset_index(drop=True, inplace=True)
x_test.reset_index(drop=True, inplace=True)

# %%
train.head()
# Out:
#                0             1            2            3            4  \
# 0  174374.804838 -12475.639482  1978.004554 -7858.336409  5860.578862
# 1  -42237.786369  -5131.472138 -1237.648009 -3622.854851 -1668.179397
# 2  -42238.277055  -5130.050216 -1169.819592 -7170.612139 -1302.887832
# 3  -42239.799375  -5132.294991 -1072.170872  -666.272834 -2029.560427
# 4  -42238.481141  -5131.398865 -1335.388327  1542.125218 -2150.267561
#
#             5            6           7           8            9  ...  \
# 0  418.165027  2039.108219  159.570096 -242.212834  1596.383278  ...
# 1 -270.150760   256.747529 -272.211165  188.974681   585.924714  ...
# 2 -264.308243    99.555085 -357.913080  274.775981   528.681077  ...
# 3 -138.083309   177.160271 -102.286180  252.744281   600.572972  ...
# 4 -250.648161   114.473620 -336.176614  324.724203   581.168354  ...
#
#             21          22          23          24           25          26  \
# ...

# %%
x_test.head()
# Out:
#                0             1            2            3            4  \
# 0  144783.386368 -12584.618022  -315.633695 -6116.649754  -954.643084
# 1  -42236.006319  -5130.146565 -1381.182131  4025.808527 -2322.465907
# 2  -42215.207833  -5122.770319 -1230.532222  8350.943294 -2287.325167
# 3  -42240.112871  -5133.177236 -1087.593655  1336.979657 -2240.345942
# 4  -42234.573712  -5127.148887 -1224.250626 -4242.992929 -1463.982515
#
#              5            6           7            8           9  ...  \
# 0 -1566.976296  1862.582414  944.567996 -2335.952421 -241.511273  ...
# 1  -246.781151   186.968739 -284.891056   232.452986  630.736097  ...
# 2   -34.521689   589.924286  505.548325  -757.528465 -217.721706  ...
# 3  -114.948668   230.951064 -120.089676   372.977117  610.138133  ...
# 4  -255.541976    77.222632 -356.853249   205.065643  538.691712  ...
#
#            20           21          22         23          24          25  \
# ...

# %%
train.to_csv('transaction.csv', index=False)
x_test.to_csv('transaction_test.csv', index=False)
